# %%
import matplotlib.pyplot as plt
import math

x = []
y = []
y1 = []

for i in range(0,10):
    xx = i * 0.1
    yy = math.exp(xx)
    x.append(xx)
    y.append(yy)
    y1.append(1/yy)
    print(yy, 1/yy)
# print(math.pow(-1, 1/4))

# a = 1/4

# x1 = pow(1, a)
# y1 = 1

# x2 = pow(1, 4*a)
# y2 = 1

# x3 = pow(-1, a)
# y3 = -1

# x4 = pow(-1, 4*a)
# y4 = -1

# x.append(x1)
# y.append(y1)
# x.append(x2)
# y.append(y2)
# x.append(x3)
# y.append(y3)
# x.append(x4)
# y.append(y4)

plt.plot(x,y)
plt.plot(x,y1)
plt.show()
# Out:
# 1.0 1.0
# 1.1051709180756477 0.9048374180359595
# 1.2214027581601699 0.8187307530779818
# 1.3498588075760032 0.7408182206817179
# 1.4918246976412703 0.6703200460356393
# 1.6487212707001282 0.6065306597126334
# 1.822118800390509 0.5488116360940264
# 2.0137527074704766 0.49658530379140947
# 2.225540928492468 0.44932896411722156
# 2.45960311115695 0.40656965974059905

# %%
이건  Pass 지수 로그를 잊어서 기억이 안난다 ㅜㅜ
