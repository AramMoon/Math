# %%
import sympy as sym
from sympy.plotting import plot
from sympy import simplify

x = sym.Symbol('x')

gx = sym.sin(sym.pi*x)**2
fx = (gx-1)**3
# plot(fx)
# simplify(fx)
simplify(fx)
plot(fx)

# %% [markdown]
# 포기
