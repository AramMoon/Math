# %%
import matplotlib.pyplot as plt
import math

x = range(0, 20)
y = []
for v in x:
    a = pow(1/9, v)
    b = pow(3, 21-4*v)
    print(a, b, a < b, v)
    y.append(a - b)
plt.plot(x,y)
plt.show()
# Out:
# 1.0 10460353203 True 0
# 0.1111111111111111 129140163 True 1
# 0.012345679012345678 1594323 True 2
# 0.001371742112482853 19683 True 3
# 0.00015241579027587256 243 True 4
# 1.6935087808430282e-05 3 True 5
# 1.8816764231589202e-06 0.037037037037037035 True 6
# 2.090751581287689e-07 0.0004572473708276177 True 7
# 2.3230573125418763e-08 5.645029269476762e-06 True 8
# 2.581174791713196e-09 6.969171937625632e-08 True 9
# 2.86797199079244e-10 8.603915972377324e-10 True 10
# 3.186635545324933e-11 1.062211848441645e-11 False 11
# 3.5407061614721473e-12 1.3113726523970925e-13 False 12
# 3.934117957191275e-13 1.618978583206287e-15 False 13
# 4.3712421746569716e-14 1.9987389916127e-17 False 14
# 4.8569357496188575e-15 2.4675790019909876e-19 False 15
# 5.396595277354285e-16 3.0463938296185032e-21 False 16
# 5.996216974838094e-17 3.7609800365660536e-23 False 17
# 6.66246330537566e-18 4.643185230328461e-25 False 18
# 7.402737005972955e-19 5.732327444849952e-27 False 19

# %% [markdown]
# 답 5. 10
